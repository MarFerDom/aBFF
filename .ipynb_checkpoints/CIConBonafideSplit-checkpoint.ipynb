# %%
import os
import featuresCIC
from datetime import datetime

files = [s for s in os.listdir("./csv/") if "output" in s]

for file in files:
    print("Reading file: "+file+"\n")
    now = datetime.now()
    print(now)
    print(os.path.basename(file))
    featuresCIC.toCIC(1, os.path.basename(file), "./csv/"+file+"/")
    
print("DONE!")
# Out:
# Reading file: output_00000_20201110020000filtered
#
# 2021-10-24 01:00:13.988683
# output_00000_20201110020000filtered
# loading cic.csv..
# calculating..
# labeling...
# saving..
# Reading file: output_00001_20201110020009filtered
#
# 2021-10-24 01:00:17.810462
# output_00001_20201110020009filtered
# loading cic.csv..
# calculating..
# labeling...
# saving..
# Reading file: output_00002_20201110020018filtered
#
# 2021-10-24 01:00:22.634179
# output_00002_20201110020018filtered
# loading cic.csv..
# calculating..
# labeling...
# saving..
# Reading file: output_00003_20201110020027filtered
#
# 2021-10-24 01:00:27.867473
# output_00003_20201110020027filtered
# loading cic.csv..
# calculating..
# labeling...
# saving..
# Reading file: output_00004_20201110020036filtered
#
# 2021-10-24 01:00:32.660240
# output_00004_20201110020036filtered
# loading cic.csv..
# calculating..
# labeling...
# saving..
# Reading file: output_00005_20201110020045filtered
#
# 2021-10-24 01:00:37.940489
# ...
